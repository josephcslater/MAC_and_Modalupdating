# %%
# %load_ext autoreload
# %autoreload 2
import vibration_toolbox as vtb
from vibration_toolbox import sdof_cf
import matplotlib.pyplot as plt
import scipy.io as sio
import math as math
import scipy.linalg as la
import numpy as np 
import pandas as pd
import vibrationtesting as vt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_file1=pd.read_csv('measurement_1.csv')
data_file2=pd.read_csv('measurement_2.csv')
data_file3=pd.read_csv('measurement_3.csv')
data_file4=pd.read_csv('measurement_4.csv')
data_file5=pd.read_csv('measurement_5.csv')
data_file6=pd.read_csv('measurement_6.csv')
data_file7=pd.read_csv('measurement_7.csv')
data_file8=pd.read_csv('measurement_8.csv')
data_file9=pd.read_csv('measurement_9.csv')
data_file10=pd.read_csv('measurement_10.csv')
data_file11=pd.read_csv('measurement_11.csv')
data_file12=pd.read_csv('measurement_12.csv')
data_file13=pd.read_csv('measurement_13.csv')
data_file14=pd.read_csv('measurement_14.csv')
data_file15=pd.read_csv('measurement_15.csv')
data_file16=pd.read_csv('measurement_16.csv')
data_file17=pd.read_csv('measurement_17.csv')
data_file18=pd.read_csv('measurement_0.csv')

# %%
print(data_file1[0:3])
# Out:
#        frq  amp_real  amp_imag
# 0  0.00000  0.080435  0.000000
# 1  0.31252  0.027379 -0.045412
# 2  0.62504  0.001081 -0.028885

# %%
# %matplotlib inline
frequencies=data_file1['frq']
magnitude1=data_file1['amp_real']+data_file1['amp_imag']*np.complex(0,1)
magnitude2=data_file2['amp_real']+data_file2['amp_imag']*np.complex(0,1)
magnitude3=data_file3['amp_real']+data_file3['amp_imag']*np.complex(0,1)
magnitude4=data_file4['amp_real']+data_file4['amp_imag']*np.complex(0,1)
magnitude5=data_file5['amp_real']+data_file5['amp_imag']*np.complex(0,1)
magnitude6=data_file6['amp_real']+data_file6['amp_imag']*np.complex(0,1)
magnitude7=data_file7['amp_real']+data_file7['amp_imag']*np.complex(0,1)
magnitude8=data_file8['amp_real']+data_file8['amp_imag']*np.complex(0,1)
magnitude9=data_file9['amp_real']+data_file9['amp_imag']*np.complex(0,1)
magnitude10=data_file10['amp_real']+data_file10['amp_imag']*np.complex(0,1)
magnitude11=data_file11['amp_real']+data_file11['amp_imag']*np.complex(0,1)
magnitude12=data_file12['amp_real']+data_file12['amp_imag']*np.complex(0,1)
magnitude13=data_file13['amp_real']+data_file13['amp_imag']*np.complex(0,1)
magnitude14=data_file14['amp_real']+data_file14['amp_imag']*np.complex(0,1)
magnitude15=data_file15['amp_real']+data_file15['amp_imag']*np.complex(0,1)
magnitude16=data_file16['amp_real']+data_file16['amp_imag']*np.complex(0,1)
magnitude17=data_file17['amp_real']+data_file17['amp_imag']*np.complex(0,1)
magnitude18=data_file18['amp_real']+data_file18['amp_imag']*np.complex(0,1)

H= (20)*(np.log10(np.abs(magnitude13[0:1600])))
plt.plot(frequencies[0:1600],H)
plt.grid('on')
plt.xlabel('$Freq,Hz$')
plt.ylabel('$H,dB$')
plt.title('$Magn$ versus $Freq$')
#H= (20)*(np.log10(np.abs(magnitude3[40:50])))
#plt.plot(frequencies[40:50], magnitude3[40:50])
#plt.grid('on')
#plt.xlabel('$Freq,Hz$')
#plt.ylabel('$H,dB$')
#plt.title('$Magn$ versus $Freq$')

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9a8ad92c50ca> in <module>()
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
# %matplotlib inline
Fmin=30
Fmax=50
f=[frequencies]
TF =[magnitude1]
 # Now we are able to call the function
 #z, nf, a = vt.mdof_cf(f,TF,500,1000)
#vt.mdof_cf(f, TF, Fmin=None, Fmax=None)
#f=np.array(f)
#TF=np.array(TF)
#new_time = dfs['XYF']['TimeUS'].astype(float)
#f=np.arange(f)
#TF=np.arange(TF)
#t.sdof_cf(f, TF, Fmin, Fmax)
#vt.mdof_cf(f, TF, Fmin=None, Fmax=None)
#z, nf, a = vt.mdof_cf(frequencies[0:1600], magnitude1[0:1600],500,1000)
#np.size(f)
sdof_cf(f, TF, Fmin, Fmax)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-72493ba190e6> in <module>()
#      16 #z, nf, a = vt.mdof_cf(frequencies[0:1600], magnitude1[0:1600],500,1000)
#      17 #np.size(f)
# ---> 18 sdof_cf(f, TF, Fmin, Fmax)
#
# ~/.local/lib/python3.5/site-packages/vibration_toolbox/ema.py in sdof_cf(f, TF, Fmin, Fmax)
#     208         inhigh = Fmax
#     209
# --> 210     if f[inlow] == 0:
#     211         inlow = 1
#     212
#
# IndexError: list index out of range

# %%
f
# Out:
# [0          0.000000
#  1          0.312520
#  2          0.625040
#  3          0.937560
#  4          1.250080
#  5          1.562600
#  6          1.875120
#  7          2.187640
#  8          2.500160
#  9          2.812680
#  10         3.125200
#  11         3.437720
#  12         3.750240
#  13         4.062760
#  14         4.375280
#  15         4.687800
#  16         5.000320
#  17         5.312840
#  18         5.625360
#  19         5.937880
#  20         6.250400
#  21         6.562920
#  22         6.875440
#  23         7.187960
#  24         7.500480
#  25         7.813000
#  26         8.125520
#  27         8.438040
#  28         8.750560
#  29         9.063080
#             ...
#  4067    1271.018845
#  4068    1271.331365
#  4069    1271.643885
#  4070    1271.956405
#  4071    1272.268925
#  4072    1272.581445
#  4073    1272.893965
#  4074    1273.206485
#  4075    1273.519005
#  4076    1273.831525
#  4077    1274.144045
#  4078    1274.456565
# ...

# %%
array.frequencies[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-631c76751d4c> in <module>()
# ----> 1 array.frequencies[0:10]
#
# NameError: name 'array' is not defined

# %%
 f=frequencies[0:500]
TF = magnitude1[0:500]
 # Now we are able to call the function
 #z, nf, a = vt.mdof_cf(f,TF,500,1000)
#vt.mdof_cf(f, TF, Fmin=None, Fmax=None)
f=np.array(f)
TF=np.array(TF)

# %%
    import sys
    sys.version
    sys.version_info
# Out:
# sys.version_info(major=3, minor=5, micro=2, releaselevel='final', serial=0)

# %%
 import vibrationtesting as vt
 import scipy.io as sio
 data = sio.loadmat(vt.__path__[0] + '/data/case2.mat')
 #print(data)
 # Data is imported as arrays. Modify then to fit our function
 TF = data['Hf_chan_2']
 f = data['Freq_domain']
 # Now we are able to call the function
 z, nf, a = vt.mdof_cf(f,TF,500,1000)

nf
# Out:
# 192.59382330288855

# %%
f
