% %% [markdown]
% # Modal Analysis of a Wing

% %%
clear all
close all
clc
%imatlab_export_fig('print-png')

% %% [markdown]
% At first natural frequency for all 18 points on the wing
% --

% %%
load FRF1.mat
load Frequencies.mat
H=20*log10(abs(x17));% in dB
f=Frequencies; % in Hz
plot(f, H)

% %%
load FRF18.mat
load Frequencies.mat
[z,nf,u118]=vtb7_4(Frequencies,x18,13.6,13.9)
% Out:
% z =
%
%     0.0074
%
%
% nf =
%
%    13.7364
%
%
% u118 =
%
%    0.4700 - 0.0000i

% %%
load FRF17.mat
load Frequencies.mat
[z,nf,u117]=vtb7_4(Frequencies,x17,13.3,13.7)
% Out:
% z =
%
%     0.1193
%
%
% nf =
%
%    13.1697
%
%
% u117 =
%
%    3.5657 - 0.0000i

% %%
load FRF16.mat
load Frequencies.mat

[z,nf,u116]=vtb7_4(Frequencies,x16,13.3,14)
% Out:
% z =
%
%     0.0135
%
%
% nf =
%
%    13.5292
%
%
% u116 =
%
%   -1.3788 - 0.0000i

% %%
load FRF15.mat
load Frequencies.mat

[z,nf,u115]=vtb7_4(Frequencies,x15,13.4,13.7)
% Out:
% z =
%
%     0.0292
%
%
% nf =
%
%    13.4455
%
%
% u115 =
%
%    1.7186 + 0.0000i

% %%
load FRF14.mat
load Frequencies.mat

[z,nf,u114]=vtb7_4(Frequencies,x14,13.4,13.5)
% Out:
% z =
%
%     0.0273
%
%
% nf =
%
%    13.5209
%
%
% u114 =
%
%    2.0494 + 0.0000i

% %%
load FRF13.mat
load Frequencies.mat

[z,nf,u113]=vtb7_4(Frequencies,x13,13.3,13.6)
% Out:
% z =
%
%     0.0184
%
%
% nf =
%
%    13.4692
%
%
% u113 =
%
%    1.5121 - 0.0000i

% %%
load FRF12.mat
load Frequencies.mat

[z,nf,u112]=vtb7_4(Frequencies,x12,13.4,13.8)
% Out:
% z =
%
%     0.0149
%
%
% nf =
%
%    13.5526
%
%
% u112 =
%
%    2.0369 + 0.0000i

% %%
load FRF11.mat
load Frequencies.mat

[z,nf,u111]=vtb7_4(Frequencies,x11,13.4,13.8)
% Out:
% z =
%
%     0.0182
%
%
% nf =
%
%    13.5409
%
%
% u111 =
%
%    2.1815 - 0.0000i

% %%
load FRF10.mat
load Frequencies.mat

[z,nf,u110]=vtb7_4(Frequencies,x10,13,14)
% Out:
% z =
%
%     0.0270
%
%
% nf =
%
%    13.5159
%
%
% u110 =
%
%    2.2772 + 0.0000i

% %%
load FRF9.mat
load Frequencies.mat

[z,nf,u19]=vtb7_4(Frequencies,x9,13.4,13.5)
% Out:
% z =
%
%     0.0197
%
%
% nf =
%
%    13.5730
%
%
% u19 =
%
%    3.3037 + 0.0000i

% %%
load FRF8.mat
load Frequencies.mat

[z,nf,u18]=vtb7_4(Frequencies,x8,13.4,13.5)
% Out:
% z =
%
%     0.0209
%
%
% nf =
%
%    13.5863
%
%
% u18 =
%
%    3.4097 - 0.0000i

% %%
load FRF7.mat
load Frequencies.mat

[z,nf,u17]=vtb7_4(Frequencies,x7,13.4,13.5)
% Out:
% z =
%
%     0.0233
%
%
% nf =
%
%    13.5700
%
%
% u17 =
%
%    3.9124 - 0.0000i

% %%
load FRF6.mat
load Frequencies.mat

[z,nf,u16]=vtb7_4(Frequencies,x6,13.4,13.5)
% Out:
% z =
%
%     0.0193
%
%
% nf =
%
%    13.5755
%
%
% u16 =
%
%    4.1108 - 0.0000i

% %%
load FRF5.mat
load Frequencies.mat

[z,nf,u15]=vtb7_4(Frequencies,x5,13.4,13.5)
% Out:
% z =
%
%     0.0172
%
%
% nf =
%
%    13.5694
%
%
% u15 =
%
%    3.9937 + 0.0000i

% %%
load FRF4.mat
load Frequencies.mat

[z,nf,u14]=vtb7_4(Frequencies,x4,13.4,13.5)
% Out:
% z =
%
%     0.0150
%
%
% nf =
%
%    13.5423
%
%
% u14 =
%
%    3.5191 - 0.0000i

% %%
load FRF3.mat
load Frequencies.mat

[z,nf,u13]=vtb7_4(Frequencies,x3,13.4,13.5)
% Out:
% z =
%
%     0.0178
%
%
% nf =
%
%    13.5659
%
%
% u13 =
%
%    4.3684 - 0.0000i

% %%
load FRF2.mat
load Frequencies.mat

[z,nf,u12]=vtb7_4(Frequencies,x2,13.4,13.5)
% Out:
% z =
%
%     0.0184
%
%
% nf =
%
%    13.5557
%
%
% u12 =
%
%    4.6872 + 0.0000i

% %%
load FRF1.mat
load Frequencies.mat

[z,nf,u11]=vtb7_4(Frequencies,x1,13.4,13.5)
% Out:
% z =
%
%     0.0185
%
%
% nf =
%
%    13.5600
%
%
% u11 =
%
%    5.2417 - 0.0000i

% %%
U=[u11 u12 u13 u14 u15 u16 u17 u18 u19 u110 u111 u112 u113 u114 u115 u116 u117 u118]'
s=real(U)
% Out:
% U =
%
%    5.2417 + 0.0000i
%    4.6872 - 0.0000i
%    4.3684 + 0.0000i
%    3.5191 + 0.0000i
%    3.9937 - 0.0000i
%    4.1108 + 0.0000i
%    3.9124 + 0.0000i
%    3.4097 + 0.0000i
%    3.3037 - 0.0000i
%    2.2772 - 0.0000i
%    2.1815 + 0.0000i
%    2.0369 - 0.0000i
%    1.5121 + 0.0000i
%    2.0494 - 0.0000i
%    1.7186 - 0.0000i
%   -1.3788 + 0.0000i
%    3.5657 + 0.0000i
%    0.4700 + 0.0000i
%
%
% s =
%
%     5.2417
%     4.6872
%     4.3684
%     3.5191
%     3.9937
%     4.1108
%     3.9124
%     3.4097
%     3.3037
%     2.2772
%     2.1815
%     2.0369
%     1.5121
%     2.0494
%     1.7186
%    -1.3788
%     3.5657
%     0.4700
